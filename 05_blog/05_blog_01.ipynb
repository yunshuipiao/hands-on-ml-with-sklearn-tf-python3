# %% [markdown]
# # SVM

# %%
# 准备工作
# To support both python 2 and python 3
from __future__ import division, print_function, unicode_literals

# Common imports
import numpy as np
import os

# to make this notebook's output stable across runs
np.random.seed(42)

# To plot pretty figures
# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
plt.rcParams['axes.labelsize'] = 14
plt.rcParams['xtick.labelsize'] = 12
plt.rcParams['ytick.labelsize'] = 12

# Where to save the figures
PROJECT_ROOT_DIR = ".."
CHAPTER_ID = "svm"

def save_fig(fig_id, tight_layout=True):
    path = os.path.join(PROJECT_ROOT_DIR, "images", CHAPTER_ID, fig_id + ".png")
    print("Saving figure", fig_id)
    if tight_layout:
        plt.tight_layout()
    plt.savefig(path, format='png', dpi=300)

# %% [markdown]
# svm是一种强大的机器学习模型，无论是线性非线性回归，分类，还是异常值检测都表现的很好。

# %% [markdown]
# ## 大间隔分类

# %%
from sklearn.svm import SVC
from sklearn import datasets

iris = datasets.load_iris()
X = iris["data"][:, (2, 3)]  # 花宽度和长度
y = iris["target"]

setosa_or_versicolor = (y == 0) | (y == 1)
X = X[setosa_or_versicolor]
y = y[setosa_or_versicolor]

# svm
svm_clf = SVC(kernel="linear", C=float("inf"))
svm_clf.fit(X, y)
# Out:
# SVC(C=inf, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
# 较差的模型
x0 = np.linspace(0, 5.5, 200)
pred_1 = 5 * x0 - 20
pred_2 = x0 - 1.8
pred_3 = 0.1 * x0 + 0.5

def plot_svc_decision_boundary(svm_clf, xmin, ymin):
    w = svm_clf.coef_[0]
    b = svm_clf.intercept_[0]
    
    # 决策边界 w0*x0+w1*x1 + b=0 -> x1 = -w0/w1 * x0 - b/w1
    x0 = np.linspace(xmin, ymin, 200)
    decision_boundary = -w[0] / w[1] * x0 - b/w[1]
    
    margin = 1/w[1]
    gutter_up = decision_boundary + margin
    gutter_down = decision_boundary - margin
    
    svs = svm_clf.support_vectors_
    plt.scatter(svs[:, 0], svs[:, 1], s=180, facecolors="#ffaaaa")
    plt.plot(x0, decision_boundary, "k-", linewidth=2)
    plt.plot(x0, gutter_up, "k--", linewidth=2)
    plt.plot(x0, gutter_down, "k--", linewidth=2)

    
plt.figure(figsize=(12, 2.7))

plt.subplot(121)
plt.plot(x0, pred_1, "g--", linewidth=2)
plt.plot(x0, pred_2, "m-", linewidth=2)
plt.plot(x0, pred_3, "r-", linewidth=2)
plt.plot(X[:, 0][y==1], X[:, 1][y==1], "bs", label="Iris-versicolor")
plt.plot(X[:, 0][y==0], X[:, 1][y==0], "yo", label="Iris-Setosa")
plt.xlabel("Petal length", fontsize=14)
plt.ylabel("Petal width", fontsize=14)
plt.legend(loc="upper left", fontsize=14)
plt.axis([0, 5.5, 0, 2])

plt.subplot(122)
plot_svc_decision_boundary(svm_clf, 0, 5.5)
plt.plot(X[:, 0][y==1], X[:, 1][y==1], "bs")
plt.plot(X[:, 0][y==0], X[:, 1][y==0], "yo")
plt.xlabel("Petal length", fontsize=14)
plt.axis([0, 5.5, 0, 2])

save_fig("large_margin_classification_plot")
plt.show()
# Out:
# Saving figure large_margin_classification_plot

# %% [markdown]
# 如上图所示进行分类。左图绿线很差。而另外两条实现则相对较好， 但是决策边界非常接近实例，因此对新实例的分类效果不好。
# 右图实线是svm分类，不仅将数据分成两类，而且决策边界远离实例。可以说svm分类拟合了最宽的街道(虚线为界)。

# %% [markdown]
# 注意，由于画出了最宽的街道， 因此在街道外添加实例并不会影响svm的分类结果。其结果完全取决于图中的两个向量(支持向量), 位于街道两边。

# %% [markdown]
# ## 特征缩放的敏感度

# %%
Xs = np.array([[1, 50], [5, 20], [3, 80], [5, 60]]).astype(np.float64)
ys = np.array([0, 0, 1, 1])
svm_clf = SVC(kernel="linear", C=100)
svm_clf.fit(Xs, ys)

plt.figure(figsize=(12,3.2))
plt.subplot(121)
plt.plot(Xs[:, 0][ys==1], Xs[:, 1][ys==1], "bo")
plt.plot(Xs[:, 0][ys==0], Xs[:, 1][ys==0], "ms")
plot_svc_decision_boundary(svm_clf, 0, 6)
plt.xlabel("$x_0$", fontsize=20)
plt.ylabel("$x_1$  ", fontsize=20, rotation=0)
plt.title("Unscaled", fontsize=16)
plt.axis([0, 6, 0, 90])

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(Xs)
svm_clf.fit(X_scaled, ys)

plt.subplot(122)
plt.plot(X_scaled[:, 0][ys==1], X_scaled[:, 1][ys==1], "bo")
plt.plot(X_scaled[:, 0][ys==0], X_scaled[:, 1][ys==0], "ms")
plot_svc_decision_boundary(svm_clf, -2, 2)
plt.xlabel("$x_0$", fontsize=20)
plt.title("Scaled", fontsize=16)
plt.axis([-2, 2, -2, 2])

save_fig("sensitivity_to_feature_scales_plot")
# Out:
# Saving figure sensitivity_to_feature_scales_plot

# %% [markdown]
# 如上图所示，svm对于特征缩放非常敏感。如上左图， 水平范围比垂直方位要小很多，因此最宽的街道接近水平。
# 而经过特征缩放后，决策边界看起来更好。

# %% [markdown]
# ## 对异常值的敏感度

# %% [markdown]
# 如果严格要求所有的实例都不在街道上，都在正确的以便， 称之为硬边缘分类器。
# 有两个问题：
# 只有数据线性可分是才有用；
# 对异常值非常敏感；
# 如下两图所示。

# %%
X_outliers = np.array([[3.4, 1.3], [3.2, 0.8]])
y_outliers = np.array([0, 0])
Xo1 = np.concatenate([X, X_outliers[:1]], axis=0)  #数组拼接
yo1 = np.concatenate([y, y_outliers[:1]], axis=0)
Xo2 = np.concatenate([X, X_outliers[1:]], axis=0)
yo2 = np.concatenate([y, y_outliers[1:]], axis=0)


svm_clf2 = SVC(kernel="linear", C=10**9)
svm_clf2.fit(Xo2, yo2)

plt.figure(figsize=(12,2.7))


plt.subplot(121)
plt.plot(Xo1[:, 0][yo1==1], Xo1[:, 1][yo1==1], "bs")
plt.plot(Xo1[:, 0][yo1==0], Xo1[:, 1][yo1==0], "yo")
plt.text(0.3, 1.0, "Impossible!", fontsize=24, color="red")
plt.xlabel("Petal length", fontsize=14)
plt.ylabel("Petal width", fontsize=14)
plt.annotate("Outlier",
             xy=(X_outliers[0][0], X_outliers[0][1]),
             xytext=(2.5, 1.7),
             ha="center",
             arrowprops=dict(facecolor='black', shrink=0.1),
             fontsize=16,
            )
plt.axis([0, 5.5, 0, 2])

plt.subplot(122)
plt.plot(Xo2[:, 0][yo2==1], Xo2[:, 1][yo2==1], "bs")
plt.plot(Xo2[:, 0][yo2==0], Xo2[:, 1][yo2==0], "yo")
plot_svc_decision_boundary(svm_clf2, 0, 5.5)
plt.xlabel("Petal length", fontsize=14)
plt.annotate("Outlier",
             xy=(X_outliers[1][0], X_outliers[1][1]),
             xytext=(3.2, 0.08),
             ha="center",
             arrowprops=dict(facecolor='black', shrink=0.1),
             fontsize=16,
            )
plt.axis([0, 5.5, 0, 2])

save_fig("sensitivity_to_outliers_plot")
plt.show()
# Out:
# Saving figure sensitivity_to_outliers_plot

# %% [markdown]
# 为了防止这种情况，需要使用更灵活的模型。目标是找到一个平衡，是街道尽可能的宽，
# 另一个是限制边界违规。(即受侵害， 即实例在街道中心甚至错误的一边)， 称之为软边缘分类。

# %% [markdown]
# ## 大间隔分类对比边界违规

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.svm import LinearSVC
from sklearn import datasets

irir = datasets.load_iris()
X = iris["data"][:, (2, 3)]  # petal length, petal width
y = (iris["target"] == 2).astype(np.float64)  # Iris-Virginica

pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("linear_svc", LinearSVC(C=1, loss="hinge", random_state=42))
])

svm_clf.fit(X, y)
# Out:
# SVC(C=100, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
svm_clf.predict([[5.5, 1.7]])
# Out:
# array([1.])

# %%
# 画出图，对比两种不同的限制设置
scaler = StandardScaler()
svm_clf1 = LinearSVC(C=1, loss='hinge', random_state=42)
svm_clf1 = LinearSVC(C=100, loss='hinge', random_state=42)

scaled_svm_clf1 = Pipeline([
        ("scaler", scaler),
        ("linear_svc", svm_clf1),
    ])
scaled_svm_clf2 = Pipeline([
        ("scaler", scaler),
        ("linear_svc", svm_clf2),
    ])

scaled_svm_clf1.fit(X, y)
scaled_svm_clf2.fit(X, y)
# Out:
# Pipeline(memory=None,
#      steps=[('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('linear_svc', SVC(C=1000000000, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False))])

# %%
# 转换未缩放的参数
# Convert to unscaled parameters
b1 = svm_clf1.decision_function([-scaler.mean_ / scaler.scale_])
b2 = svm_clf2.decision_function([-scaler.mean_ / scaler.scale_])
w1 = svm_clf1.coef_[0] / scaler.scale_
w2 = svm_clf2.coef_[0] / scaler.scale_
# svm_clf2.coef_ = np.array([w2])
# svm_clf1.coef_ = np.array([w1])
# svm_clf1.intercept_ = np.array([b1])
# svm_clf2.intercept_ = np.array([b2])

# Find support vectors (LinearSVC does not do this automatically)
t = y * 2 - 1
support_vectors_idx1 = (t * (X.dot(w1) + b1) < 1).ravel()
support_vectors_idx2 = (t * (X.dot(w2) + b2) < 1).ravel()
svm_clf1.support_vectors_ = X[support_vectors_idx1]
svm_clf2.support_vectors_ = X[support_vectors_idx2]

# %%
# 可视化
# plt.figure(figsize=(12,3.2))
# plt.subplot(121)
# plt.plot(X[:, 0][y==1], X[:, 1][y==1], "g^", label="Iris-Virginica")
# plt.plot(X[:, 0][y==0], X[:, 1][y==0], "bs", label="Iris-Versicolor")
# plot_svc_decision_boundary(svm_clf1, 4, 6)
# plt.xlabel("Petal length", fontsize=14)
# plt.ylabel("Petal width", fontsize=14)
# plt.legend(loc="upper left", fontsize=14)
# plt.title("$C = {}$".format(svm_clf1.C), fontsize=16)
# plt.axis([4, 6, 0.8, 2.8])

# plt.subplot(122)
# plt.plot(X[:, 0][y==1], X[:, 1][y==1], "g^")
# plt.plot(X[:, 0][y==0], X[:, 1][y==0], "bs")
# plot_svc_decision_boundary(svm_clf2, 4, 6)
# plt.xlabel("Petal length", fontsize=14)
# plt.title("$C = {}$".format(svm_clf2.C), fontsize=16)
# plt.axis([4, 6, 0.8, 2.8])

# save_fig("regularization_plot")

# %% [markdown]
# 结果如下：
# ![%E5%B1%8F%E5%B9%95%E5%BF%AB%E7%85%A7%202018-04-30%2016.38.39.png](attachment:%E5%B1%8F%E5%B9%95%E5%BF%AB%E7%85%A7%202018-04-30%2016.38.39.png)

# %% [markdown]
# 如上图所示， 在sklearn中可以控制C超参数达到平衡：小的C有较宽的街道，但是会有违规边界。
# 而较大的C有更少的违规边界，但是街道较小。
# 如果svm模型过拟合，可以通过减少c加以限制。

# %% [markdown]
# ## 非线性分类

# %% [markdown]
# 尽管线性模型在很多情况下都很有效，但更多的数据是线性不可分的。
# 一种处理方法是添加更多的特征使其线性可分。

# %%
X1D = np.linspace(-4, 4, 9).reshape(-1, 1)
X2D = np.c_[X1D, X1D ** 2]
y = np.array([0, 0, 1, 1, 1, 1, 1, 0, 0])

plt.figure(figsize=(11, 4))

plt.subplot(121)
plt.grid(True, which='both')
plt.axhline(y=0, color='k')
plt.plot(X1D[:, 0][y==0], np.zeros(4), "bs")
plt.plot(X1D[:, 0][y==1], np.zeros(5), "g^")
plt.gca().get_yaxis().set_ticks([])
plt.xlabel(r"$x_1$", fontsize=20)
plt.axis([-4.5, 4.5, -0.2, 0.2])

plt.subplot(122)
plt.grid(True, which='both')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')

plt.plot(X2D[:, 0][y==0], X2D[:, 1][y==0], "bs")
plt.plot(X2D[:, 0][y==1], X2D[:, 1][y==1], "g^")
plt.xlabel(r"$x_1$", fontsize=20)
plt.ylabel(r"$x_2$", fontsize=20, rotation=0)
plt.gca().get_yaxis().set_ticks([0, 4, 8, 12, 16])
plt.plot([-4.5, 4.5], [6.5, 6.5], "r--", linewidth=3)
plt.axis([-4.5, 4.5, -1, 17])

plt.subplots_adjust(right=1)

save_fig("higher_dimensions_plot", tight_layout=False)
plt.show()
# Out:
# Saving figure higher_dimensions_plot

# %% [markdown]
# 比如上左图，添加第二个特征， 就能线性分开。

# %% [markdown]
# ----

# %%
from sklearn.datasets import make_moons
X, y = make_moons(n_samples=100, noise=0.15, random_state=42) #旋涡数据

def plot_dataset(X, y, axes):
    plt.plot(X[:, 0][y==0], X[:, 1][y==0], "bs")
    plt.plot(X[:, 0][y==1], X[:, 1][y==1], "g^")
    plt.axis(axes)
    plt.grid(True, which='both')
    plt.xlabel(r"$x_1$", fontsize=20)
    plt.ylabel(r"$x_2$", fontsize=20, rotation=0)

plot_dataset(X, y, [-1.5, 2.5, -1, 1.5])
plt.show()

# %%
from sklearn.datasets import  make_moons
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import PolynomialFeatures

polynomial_svm_clf = Pipeline([
    ("poly_features", PolynomialFeatures(degree=3)),
    ("scaler", StandardScaler()),
    ("svm_clf", LinearSVC(C=10, loss="hinge", random_state=42))
])

polynomial_svm_clf.fit(X, y)
# Out:
# Pipeline(memory=None,
#      steps=[('poly_features', PolynomialFeatures(degree=3, include_bias=True, interaction_only=False)), ('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('svm_clf', LinearSVC(C=10, class_weight=None, dual=True, fit_intercept=True,
#      intercept_scaling=1, loss='hinge', max_iter=1000, multi_class='ovr',
#      penalty='l2', random_state=42, tol=0.0001, verbose=0))])

# %%
def plot_predictions(clf, axes):
    x0s = np.linspace(axes[0], axes[1], 100)
    x1s = np.linspace(axes[2], axes[3], 100)
    x0, x1 = np.meshgrid(x0s, x1s)
    X = np.c_[x0.ravel(), x1.ravel()]
    y_pred = clf.predict(X).reshape(x0.shape)
    y_decision = clf.decision_function(X).reshape(x0.shape)
    plt.contourf(x0, x1, y_pred, cmap=plt.cm.brg, alpha=0.2)
    plt.contourf(x0, x1, y_decision, cmap=plt.cm.brg, alpha=0.1)
    
plot_predictions(polynomial_svm_clf, [-1.5, 2.5, -1, 1.5])
plot_dataset(X, y, [-1.5, 2.5, -1, 1.5])

save_fig("moons_polynomial_svc_plot")
plt.show()
# Out:
# Saving figure moons_polynomial_svc_plot

# %% [markdown]
# ## 多项式内核

# %% [markdown]
# 添加多项式特征可以简单却有效处理各种各样的机器学习算法(不仅是svm)， 低阶多项式难以处理复杂数据，而高阶多项式将会是特征过多，训练变慢。
# 幸运的是，svm有一种叫kerne trick的数学方法，可以得到相同的结果，就像添加了许多项式特征，实际上并没有添加。

# %%
from sklearn.svm import SVC

poly_kernel_svm_clf = Pipeline([
    ("scaler", StandardScaler()), 
    ("svm_clf", SVC(kernel="poly", degree=3, coef0=1, C=5))
])

poly_kernel_svm_clf.fit(X, y)
# Out:
# Pipeline(memory=None,
#      steps=[('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('svm_clf', SVC(C=5, cache_size=200, class_weight=None, coef0=1,
#   decision_function_shape='ovr', degree=3, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False))])

# %%
poly100_kernel_svm_clf = Pipeline([
        ("scaler", StandardScaler()),
        ("svm_clf", SVC(kernel="poly", degree=10, coef0=100, C=5))
    ])
poly100_kernel_svm_clf.fit(X, y)
# Out:
# Pipeline(memory=None,
#      steps=[('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('svm_clf', SVC(C=5, cache_size=200, class_weight=None, coef0=100,
#   decision_function_shape='ovr', degree=10, gamma='auto', kernel='poly',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False))])

# %%
plt.figure(figsize=(11, 4))

plt.subplot(121)
plot_predictions(poly_kernel_svm_clf, [-1.5, 2.5, -1, 1.5])
plot_dataset(X, y, [-1.5, 2.5, -1, 1.5])
plt.title(r"$d=3, r=1, C=5$", fontsize=18)

plt.subplot(122)
plot_predictions(poly100_kernel_svm_clf, [-1.5, 2.5, -1, 1.5])
plot_dataset(X, y, [-1.5, 2.5, -1, 1.5])
plt.title(r"$d=10, r=100, C=5$", fontsize=18)

save_fig("moons_kernelized_polynomial_svc_plot")
plt.show()
# Out:
# Saving figure moons_kernelized_polynomial_svc_plot

# %% [markdown]
# 如上图，不同的degree可以控制模型的拟合程度，而coef0 则是控制模型受高阶多项式和低阶多项式的影响程度。

# %% [markdown]
# ## 添加相似的特征

# %% [markdown]
# 处理非线性问题的另一种方法是添加使用相似函数计算的特征，该函数度量每个实例与一个特定的界标的相似程度。
# 高斯径向基函数(RBF)。

# %%
def gaussian_rbf(x, landmark, gamma):
    return np.exp(-gamma * np.linalg.norm(x - landmark, axis=1) ** 2)

gamma = 0.3

x1s = np.linspace(-4.5, 4.5, 200).reshape(-1, 1)
x2s = gaussian_rbf(x1s, -2, gamma)
x3s = gaussian_rbf(x1s, 1, gamma)


XK = np.c_[gaussian_rbf(X1D, -2, gamma), gaussian_rbf(X1D, 1, gamma)]
yk = np.array([0, 0, 1, 1, 1, 1, 1, 0, 0])

plt.figure(figsize=(11, 4))

plt.subplot(121)
plt.grid(True, which='both')
plt.axhline(y=0, color='k')
plt.scatter(x=[-2, 1], y=[0, 0], s=150, alpha=0.5, c="red")
plt.plot(X1D[:, 0][yk==0], np.zeros(4), "bs")
plt.plot(X1D[:, 0][yk==1], np.zeros(5), "g^")
plt.plot(x1s, x2s, "g--")
plt.plot(x1s, x3s, "b:")
plt.gca().get_yaxis().set_ticks([0, 0.25, 0.5, 0.75, 1])
plt.xlabel(r"$x_1$", fontsize=20)
plt.ylabel(r"Similarity", fontsize=14)
plt.annotate(r'$\mathbf{x}$',
             xy=(X1D[3, 0], 0),
             xytext=(-0.5, 0.20),
             ha="center",
             arrowprops=dict(facecolor='black', shrink=0.1),
             fontsize=18,
            )
plt.text(-2, 0.9, "$x_2$", ha="center", fontsize=20)
plt.text(1, 0.9, "$x_3$", ha="center", fontsize=20)
plt.axis([-4.5, 4.5, -0.1, 1.1])

plt.subplot(122)
plt.grid(True, which='both')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.plot(XK[:, 0][yk==0], XK[:, 1][yk==0], "bs")
plt.plot(XK[:, 0][yk==1], XK[:, 1][yk==1], "g^")
plt.xlabel(r"$x_2$", fontsize=20)
plt.ylabel(r"$x_3$  ", fontsize=20, rotation=0)
plt.annotate(r'$\phi\left(\mathbf{x}\right)$',
             xy=(XK[3, 0], XK[3, 1]),
             xytext=(0.65, 0.50),
             ha="center",
             arrowprops=dict(facecolor='black', shrink=0.1),
             fontsize=18,
            )
plt.plot([-0.1, 1.1], [0.57, -0.1], "r--", linewidth=3)
plt.axis([-0.1, 1.1, -0.1, 1.1])
    
plt.subplots_adjust(right=1)

save_fig("kernel_method_plot")
plt.show()
# Out:
# Saving figure kernel_method_plot

# %%
x1_example = X1D[3, 0]
for landmark in (-2, 1):
    k = gaussian_rbf(np.array([[x1_example]]), np.array([[landmark]]), gamma)
    print("Phi({}, {}) = {}".format(x1_example, landmark, k))
# Out:
# Phi(-1.0, -2) = [0.74081822]
# Phi(-1.0, 1) = [0.30119421]

# %% [markdown]
# ## 高斯径向基函数(RBF) 内核

# %%
rbf_kernel_svm_clf = Pipeline([
        ("scaler", StandardScaler()),
        ("svm_clf", SVC(kernel="rbf", gamma=5, C=0.001))
    ])
rbf_kernel_svm_clf.fit(X, y)
# Out:
# Pipeline(memory=None,
#      steps=[('scaler', StandardScaler(copy=True, with_mean=True, with_std=True)), ('svm_clf', SVC(C=0.001, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=5, kernel='rbf',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False))])

# %%
from sklearn.svm import SVC

gamma1, gamma2 = 0.1, 5
C1, C2 = 0.001, 1000
hyperparams = (gamma1, C1), (gamma1, C2), (gamma2, C1), (gamma2, C2)

svm_clfs = []
for gamma, C in hyperparams:
    rbf_kernel_svm_clf = Pipeline([
            ("scaler", StandardScaler()),
            ("svm_clf", SVC(kernel="rbf", gamma=gamma, C=C))
        ])
    rbf_kernel_svm_clf.fit(X, y)
    svm_clfs.append(rbf_kernel_svm_clf)

plt.figure(figsize=(11, 7))

for i, svm_clf in enumerate(svm_clfs):
    plt.subplot(221 + i)
    plot_predictions(svm_clf, [-1.5, 2.5, -1, 1.5])
    plot_dataset(X, y, [-1.5, 2.5, -1, 1.5])
    gamma, C = hyperparams[i]
    plt.title(r"$\gamma = {}, C = {}$".format(gamma, C), fontsize=16)

save_fig("moons_rbf_svc_plot")
plt.show()
# Out:
# Saving figure moons_rbf_svc_plot

# %% [markdown]
# 其中，增加gamma值会使曲线变狭窄，因此，每个实例的影响范围更小:决策边界最终变得更加不规则，围绕单个实例进行摆动。
# 反之，决策边界更加平滑。gamma表现的像限制类的超参数。 如果模型过拟合，应该减小， 模型欠拟合，应该增加。
#
# 还有其余内核，不过用的很少。
# 因此如何决定使用什么内核？首选线性内核，(linearSVC 要比SVC 要快)， 尤其是数据集很大 ，或者有大量的特征。
# 如果训练集不是很大，应该使用RBF ，大部分情况下效果都很好。 如时间充足，计算性能强，可以使用交叉验证去尝试不同的内核。

# %% [markdown]
# ### 计算性能对比
# ![%E5%B1%8F%E5%B9%95%E5%BF%AB%E7%85%A7%202018-04-30%2018.22.37.png](attachment:%E5%B1%8F%E5%B9%95%E5%BF%AB%E7%85%A7%202018-04-30%2018.22.37.png)

# %% [markdown]
# ## SVM回归

# %% [markdown]
# 之前提到svm不仅可以处理分类，还可以处理回归。
# 因此现在的目标变为：不是在限定边缘违规的情况下求不同类别的最大间距， 而是给定限定边缘的情况下，尽可能多的使数据位于街道上。
# 此时街道的宽度由$\epsilon$超参数控制。

# %%
np.random.seed(42)
m = 50
X = 2 * np.random.rand(m, 1)
y = (4 + 3 * X + np.random.randn(m ,1)).ravel()

# %%
from sklearn.svm import LinearSVR
svm_reg = LinearSVR(epsilon=1.5, random_state=42)
svm_reg.fit(X, y)
# Out:
# LinearSVR(C=1.0, dual=True, epsilon=1.5, fit_intercept=True,
#      intercept_scaling=1.0, loss='epsilon_insensitive', max_iter=1000,
#      random_state=42, tol=0.0001, verbose=0)

# %%
svm_reg1 = LinearSVR(epsilon=1.5, random_state=42)
svm_reg2 = LinearSVR(epsilon=0.5, random_state=42)
svm_reg1.fit(X, y)
svm_reg2.fit(X, y)

def find_support_vectors(svm_reg, X, y):
    y_pred = svm_reg.predict(X)
    off_margin = (np.abs(y - y_pred) >= svm_reg.epsilon)
    return np.argwhere(off_margin)

svm_reg1.support_ = find_support_vectors(svm_reg1, X, y)
svm_reg2.support_ = find_support_vectors(svm_reg2, X, y)

eps_x1 = 1
eps_y_pred = svm_reg1.predict([[eps_x1]])

# %%
def plot_svm_regression(svm_reg, X, y, axes):
    x1s = np.linspace(axes[0], axes[1], 100).reshape(100, 1)
    y_pred = svm_reg.predict(x1s)
    plt.plot(x1s, y_pred, "k-", linewidth=2, label="$\hat{y}$")
    plt.plot(x1s, y_pred + svm_reg.epsilon, "k--")
    plt.plot(x1s, y_pred - svm_reg.epsilon, "k--")
    plt.scatter(X[svm_reg.support_], y[svm_reg.support_], s=180, facecolors='#FFAAAA')
    plt.plot(X, y, "bo")
    plt.xlabel(r"$x_1$", fontsize=18)
    plt.legend(loc="upper left", fontsize=18)
    plt.axis(axes)

plt.figure(figsize=(9, 4))
plt.subplot(121)
plot_svm_regression(svm_reg1, X, y, [0, 2, 3 ,11])
plt.title("$\epsilon={}$".format(svm_reg1.epsilon), fontsize=18)
plt.ylabel(r"$y$", fontsize=18, rotation=0)
plt.annotate(
        '', xy=(eps_x1, eps_y_pred), xycoords='data',
        xytext=(eps_x1, eps_y_pred - svm_reg1.epsilon),
        textcoords='data', arrowprops={'arrowstyle': '<->', 'linewidth': 1.5}
    )
plt.text(0.91, 5.6, r"$\epsilon$", fontsize=20)

plt.subplot(122)
plot_svm_regression(svm_reg2, X, y, [0, 2, 3, 11])
plt.title(r"$\epsilon = {}$".format(svm_reg2.epsilon), fontsize=18)
save_fig("svm_regression_plot")
plt.show()
# Out:
# Saving figure svm_regression_plot

# %% [markdown]
# 如上图所示，不同的超参数可以得到不同的结果。 在街道内添加数据不会影响结果分类， 称为$\epsilon$-insensitive.

# %%
np.random.seed(42)
m = 100
X = 2 * np.random.rand(m, 1) - 1
y = (0.2 + 0.1 * X + 0.5 * X ** 2 + np.random.randn(m, 1) / 10).ravel()

# %% [markdown]
# 如果是处理非线性回归任务，可以使用内核化的svm模型。

# %%
from sklearn.svm import SVR

svm_poly_reg = SVR(kernel="poly", degree=2, C=100, epsilon=0.1)
svm_poly_reg.fit(X, y)
# Out:
# SVR(C=100, cache_size=200, coef0=0.0, degree=2, epsilon=0.1, gamma='auto',
#   kernel='poly', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
svm_poly_reg1 = SVR(kernel="poly", degree=2, C=100, epsilon=0.1)
svm_poly_reg2 = SVR(kernel="poly", degree=2, C=0.01, epsilon=0.1)
svm_poly_reg1.fit(X, y)
svm_poly_reg2.fit(X, y)
# Out:
# SVR(C=0.01, cache_size=200, coef0=0.0, degree=2, epsilon=0.1, gamma='auto',
#   kernel='poly', max_iter=-1, shrinking=True, tol=0.001, verbose=False)

# %%
plt.figure(figsize=(9, 4))
plt.subplot(121)
plot_svm_regression(svm_poly_reg1, X, y, [-1, 1, 0, 1])
plt.title(r"$degree={}, C={}, \epsilon = {}$".format(svm_poly_reg1.degree, svm_poly_reg1.C, svm_poly_reg1.epsilon), fontsize=18)
plt.ylabel(r"$y$", fontsize=18, rotation=0)
plt.subplot(122)
plot_svm_regression(svm_poly_reg2, X, y, [-1, 1, 0, 1])
plt.title(r"$degree={}, C={}, \epsilon = {}$".format(svm_poly_reg2.degree, svm_poly_reg2.C, svm_poly_reg2.epsilon), fontsize=18)
save_fig("svm_with_polynomial_kernel_plot")
plt.show()
# Out:
# Saving figure svm_with_polynomial_kernel_plot

# %% [markdown]
# 如上图， 左边结果是有一点限制的2阶多项式模型(C很大), 右图是有较大限制的模型(C很小)。

# %% [markdown]
# svm还可以用于异常值检测，查看sklearn文档。

# %% [markdown]
# ## 加深理解

# %% [markdown]
# 做svm如何做预测，以及怎么训练算法做个解释。
# 首先说明一点， 之前约定模型中的所有权重参数为$\theta$, 偏置项$\theta_0$以及权重$\theta_1$ 到 $\theta_n$， 对于偏置项，添加x0=1,视为全部特征。
# 而本章中，使用另一个更普遍，更常用的约定。  偏置项称为 b， 特征权重向量称为 w。

# %% [markdown]
# ### 决策函数和预测

# %% [markdown]
# 线性svm分类器预测输入x的类别，是通过计算决策函数 $w^{T} \cdot x + b =w_1 x_1 + ... + w_n x_n + b$: 如果结果为正， 则分类为1否则为0.

# %% [markdown]
# ![%E5%B1%8F%E5%B9%95%E5%BF%AB%E7%85%A7%202018-04-30%2023.51.07.png](attachment:%E5%B1%8F%E5%B9%95%E5%BF%AB%E7%85%A7%202018-04-30%2023.51.07.png)
# 上图的虚线表示决策函数等于1或者-1的情况：平行且与决策边界相等，形成一个边界。
# 训练线性svm就是找到w和b的过程，且使边界间隔足够大，并且回避边缘违规(硬边缘)或者进行限制(软边缘).

# %% [markdown]
# ### 训练目标
# 考虑决策函数的斜率：等于权重向量w的范数。如果除以2， 决策函数边界+1和-1，决策边界远离2倍。
# 斜率除以2， 边界间隔乘以2， 扩大2倍。
# 因此，目标是最小化$\left \| w \right \|$去获得大间隔。 同时也要回避比边缘违规，需要决策函数对于分类为1的实例， 结果大于1；反之小于1.
# 对于所有负实例(y=0), 定义$t^{(i)}=-1$;正实例(y=1)定义$t^{(i)}=1$。
# 对于所有实例，就可以用$t^{(i)}(w^{T} \cdot x^{i} + b) \geq 1 $ 约束。

# %% [markdown]
# 这里贴一段原文:
# ![%E5%B1%8F%E5%B9%95%E5%BF%AB%E7%85%A7%202018-05-01%2000.16.03.png](attachment:%E5%B1%8F%E5%B9%95%E5%BF%AB%E7%85%A7%202018-05-01%2000.16.03.png)

# %% [markdown]
# ## 权重向量对结果的印象

# %%
def plot_2D_decision_function(w, b, ylabel=True, x1_lim=[-3, 3]):
    x1 = np.linspace(x1_lim[0], x1_lim[1], 200)
    y = w * x1 + b
    m = 1 / w

    plt.plot(x1, y)
    plt.plot(x1_lim, [1, 1], "k:")
    plt.plot(x1_lim, [-1, -1], "k:")
    plt.axhline(y=0, color='k')
    plt.axvline(x=0, color='k')
    plt.plot([m, m], [0, 1], "k--")
    plt.plot([-m, -m], [0, -1], "k--")
    plt.plot([-m, m], [0, 0], "k-o", linewidth=3)
    plt.axis(x1_lim + [-2, 2])
    plt.xlabel(r"$x_1$", fontsize=16)
    if ylabel:
        plt.ylabel(r"$w_1 x_1$  ", rotation=0, fontsize=16)
    plt.title(r"$w_1 = {}$".format(w), fontsize=16)

plt.figure(figsize=(12, 3.2))
plt.subplot(121)
plot_2D_decision_function(1, 0)
plt.subplot(122)
plot_2D_decision_function(0.5, 0, ylabel=False)
save_fig("small_w_large_margin_plot")
plt.show()
# Out:
# Saving figure small_w_large_margin_plot

# %%
from sklearn.svm import SVC
from sklearn import datasets

iris = datasets.load_iris()
X = iris["data"][:, (2, 3)] # petal length, petal width
y = (iris["target"] == 2).astype(np.float64) # Iris-Virginica

svm_clf = SVC(kernel="linear", C=1)
svm_clf.fit(X, y)
svm_clf.predict([[5.3, 1.3]])
# Out:
# array([1.])

# %% [markdown]
# ### 二次方程
# 硬边和软边问题都是带有线性约束的凸二次优化问题。这些问题被称为二次规划问题(QP)。
# 然而，要使用内核技巧，我们将考虑一个不同的约束优化问题。
# ###  对偶问题
# 考虑到一个被称为原始问题的约束优化问题，它是可以表达一个不同但又密切相关的问题的，称为它的双重问题。对偶问题的溶解度通常会降低原始问题的解，但在某些条件下，它甚至可以有与原始问题相同的解。
#
#
# ### 在线svm
# 在线学习意味着逐步学习，通常是在新实例到达时。
# 对于线性SVM分类器，一种方法是使用梯度下降法将公式中的成本函数最小化，这是源于原始问题。不幸的是，它的收敛速度要比基于QP的方法慢得多。
# ![%E5%B1%8F%E5%B9%95%E5%BF%AB%E7%85%A7%202018-05-01%2000.22.55.png](attachment:%E5%B1%8F%E5%B9%95%E5%BF%AB%E7%85%A7%202018-05-01%2000.22.55.png)
#
# 最小化这一术语可以确保模型使边缘违规行为尽可能小，并且尽可能少。

# %% [markdown]
# ## hinge损失函数

# %%
t = np.linspace(-2, 4 ,200)
h = np.where(1 - t < 0, 0, 1 - t) # max(0, 1-t)

plt.figure(figsize=(5,2.8))
plt.plot(t, h, "b-", linewidth=2, label="$max(0, 1 - t)$")
plt.grid(True, which='both')
plt.axhline(y=0, color='k')
plt.axvline(x=0, color='k')
plt.yticks(np.arange(-1, 2.5, 1))
plt.xlabel("$t$", fontsize=16)
plt.axis([-2, 4, -1, 2.5])
plt.legend(loc="upper right", fontsize=16)
save_fig("hinge_plot")
plt.show()
# Out:
# Saving figure hinge_plot

# %% [markdown]
# ## 补充资料

# %% [markdown]
# ### 课后习题

# %% [markdown]
# #### 1. svm的基本思想

# %% [markdown]
# #### 2. 什么是支持向量

# %% [markdown]
# #### 3. 为什么特征缩放对于svm非常重要

# %% [markdown]
# #### 4. 当一个SVM分类器对一个实例进行分类时，它能输出一个置信值吗?一个概率呢?

# %% [markdown]
# #### 5. 是否应该使用SVM的原始或双重形式来训练具有数百万个实例和数百个特性的训练集的模型?

# %% [markdown]
# #### 6. 使用高斯径向基函数训练svm分类器，如果欠拟合，应该怎么调节参数$\gamma$ 和C两个超参数。

# %% [markdown]
# #### 7. 你应该如何设置QP参数(H, f, A, b)来解决使用现成的QP求解器的软边缘线性SVM分类器问题

# %% [markdown]
# #### 8. 在线性可分数据集上训练线性svc。然后在同一数据集上训练SVC和SGDClassifier。看看能否让他们生产出大致相同的模型。

# %% [markdown]
# #### 9. 在MNIST数据集上训练SVM分类器。由于SVM分类器是二进制分类器， 应该怎么进行多分类？可能想要使用小的验证集来调整超参数以加速进程。你能达到什么精度?

# %% [markdown]
# #### 10. 训练一个svm回归模型，用于预测房价。
